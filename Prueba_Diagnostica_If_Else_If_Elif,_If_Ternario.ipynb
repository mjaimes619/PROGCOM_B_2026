# %% [markdown]
# <a href="https://colab.research.google.com/github/mjaimes619/PROGCOM_B_2026/blob/main/Prueba_Diagnostica_If_Else_If_Elif%2C_If_Ternario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 1 IF/ELSE
base = float(input("Ingresa la base: "))
altura = float(input("Ingresa la altura: "))

if base > 0 and altura > 0:
    area = (base * altura) / 2
    print(f"El área del triángulo es: {area}")
else:
    print("La base y la altura deben ser mayores a 0")
# Out:
# Ingresa la base: 3
# Ingresa la altura: 4
# El área del triángulo es: 6.0

# %%
## 1 IF/ELIF
base = float(input("Ingresa la base: "))
altura = float(input("Ingresa la altura: "))

if base <= 0:
    print("La base debe ser mayor a 0")
elif altura <= 0:
    print("La altura debe ser mayor a 0")
elif base > 0 and altura > 0:
    area = (base * altura) / 2
    print(f"El área del triángulo es: {area}")
# Out:
# Ingresa la base: 3
# Ingresa la altura: 4
# El área del triángulo es: 6.0

# %%
## 1 IF TERNARIO
base = float(input("Ingresa la base: "))
altura = float(input("Ingresa la altura: "))

area = (base * altura) / 2 if base > 0 and altura > 0 else "Valores inválidos"

print(f"El área del triángulo es: {area}")
# Out:
# Ingresa la base: 3
# Ingresa la altura: 4
# El área del triángulo es: 6.0

# %%
##2 IF/ELSE
celsius = float(input("Ingresa la temperatura en Celsius: "))

if celsius >= -273.15:
    fahrenheit = (celsius * 9/5) + 32
    print(f"{celsius} °C = {fahrenheit} °F")
else:
    print("Temperatura inválida, no puede ser menor al cero absoluto (-273.15°C)")
# Out:
# Ingresa la temperatura en Celsius: 30
# 30.0 °C = 86.0 °F

# %%
## 2 IF/ELIF
celsius = float(input("Ingresa la temperatura en Celsius: "))

if celsius < -273.15:
    print("Temperatura inválida, no puede ser menor al cero absoluto (-273.15°C)")
elif celsius < 0:
    fahrenheit = (celsius * 9/5) + 32
    print("Temperatura bajo cero:", celsius, "°C =", fahrenheit, "°F")
elif celsius == 0:
    print("Es el punto de congelación del agua: 0°C = 32°F")
elif celsius == 100:
    print("Es el punto de ebullición del agua: 100°C = 212°F")
elif celsius > 0:
    fahrenheit = (celsius * 9/5) + 32
    print(f"{celsius} °C = {fahrenheit} °F")
# Out:
# Ingresa la temperatura en Celsius: 30
# 30.0 °C = 86.0 °F

# %%
## 2 IF TERNARIO
celsius = float(input("Ingresa la temperatura en Celsius: "))

farenheith = str((celsius * 9/5) + 32) + " °F" if celsius >= -273.15 else "Temperatura inválida"

print(f"{celsius} °C = {fahrenheit} °F")
# Out:
# Ingresa la temperatura en Celsius: 30
# 30.0 °C = 86.0 °F

# %%
## 3 IF/ELSE
n1 = float(input("Ingresa el primer número: "))
n2 = float(input("Ingresa el segundo número: "))
n3 = float(input("Ingresa el tercer número: "))

promedio = (n1 + n2 + n3) / 3

if promedio >= 3:
    print(f"Promedio: {promedio} - Aprobado")
else:
    print(f"Promedio: {promedio} - Reprobado")
# Out:
# Ingresa el primer número: 2.4
# Ingresa el segundo número: 5
# Ingresa el tercer número: 2.9
# Promedio: 3.4333333333333336 - Aprobado

# %%
## 3 IF/ELIF
n1 = float(input("Ingresa el primer número: "))
n2 = float(input("Ingresa el segundo número: "))
n3 = float(input("Ingresa el tercer número: "))

promedio = (n1 + n2 + n3) / 3

if promedio >= 4.5:
    print(f"Promedio: {promedio} - Excelente")
elif promedio >= 3.75:
    print(f"Promedio: {promedio} - Bueno")
elif promedio >= 3:
    print(f"Promedio: {promedio} - Aprobado")
elif promedio >= 0:
    print(f"Promedio: {promedio} - Reprobado")
else:
    print("Promedio inválido")
# Out:
# Ingresa el primer número: 2.4
# Ingresa el segundo número: 5
# Ingresa el tercer número: 2.9
# Promedio: 3.4333333333333336 - Aprobado

# %%
## 3 IF TERNARIO
n1 = float(input("Ingresa el primer número: "))
n2 = float(input("Ingresa el segundo número: "))
n3 = float(input("Ingresa el tercer número: "))

promedio = (n1 + n2 + n3) / 3

materia = "Aprobado" if promedio >= 3 else "Reprobado"

print(f"Promedio: {promedio} {materia}")
# Out:
# Ingresa el primer número: 3
# Ingresa el segundo número: 4
# Ingresa el tercer número: 1
# Promedio: 2.6666666666666665 Reprobado

# %%
## 4 IF/ELIF
radio = float(input("Ingresa el radio del círculo: "))
pi = 3.14159

if radio > 0:
    area = pi * radio * radio
    perimetro = 2 * pi * radio
    print(f"Área: {area}")
    print(f"Perímetro: {perimetro}")
else:
    print("El radio debe ser mayor a 0")
# Out:
# Ingresa el radio del círculo: 3
# Área: 28.274309999999996
# Perímetro: 18.849539999999998

# %%
## 4 IF/ELIF
radio = float(input("Ingresa el radio del círculo: "))
pi = 3.14159

if radio < 0:
    print("El radio no puede ser negativo")
elif radio == 0:
    print("El radio no puede ser cero")
elif radio > 0:
    area = pi * radio * radio
    perimetro = 2 * pi * radio
    print(f"Área: {area}")
    print(f"Perímetro: {perimetro}")
# Out:
# Ingresa el radio del círculo: 3
# Área: 28.274309999999996
# Perímetro: 18.849539999999998

# %%
## 4 IF TERNARIO
radio = float(input("Ingresa el radio del círculo: "))
pi = 3.14159

area = pi * radio * radio if radio > 0 else "Radio inválido"
perimetro = 2 * pi * radio if radio > 0 else "Radio inválido"

print(f"Área: {area}")
print(f"Perímetro: {perimetro}")
# Out:
# Ingresa el radio del círculo: 3
# Área: 28.274309999999996
# Perímetro: 18.849539999999998

# %%
## 5 IF/ELSE
a = float(input("Ingresa el valor de a: "))
b = float(input("Ingresa el valor de b: "))
c = float(input("Ingresa el valor de c: "))

if a == 0:
    print("No es una ecuación cuadrática (a no puede ser 0)")
else:
    discriminante = b * b - 4 * a * c
    if discriminante >= 0:
        x1 = (-b + discriminante ** 0.5) / (2 * a)
        x2 = (-b - discriminante ** 0.5) / (2 * a)
        print(f"x1 = {x1}")
        print(f"x2 = {x2}")
    else:
        print("No tiene soluciones reales")
# Out:
# Ingresa el valor de a: -1
# Ingresa el valor de b: 4
# Ingresa el valor de c: 3
# x1 = -0.6457513110645907
# x2 = 4.645751311064591

# %%
## 5 IF/ELIF
a = float(input("Ingresa el valor de a: "))
b = float(input("Ingresa el valor de b: "))
c = float(input("Ingresa el valor de c: "))

discriminante = b * b - 4 * a * c

if a == 0:
    print("No es una ecuación cuadrática (a no puede ser 0)")
elif discriminante > 0:
    x1 = (-b + discriminante ** 0.5) / (2 * a)
    x2 = (-b - discriminante ** 0.5) / (2 * a)
    print("Dos soluciones reales:")
    print(f"x1 = {x1}")
    print(f"x2 = {x2}")
elif discriminante == 0:
    x = -b / (2 * a)
    print("Una solución real:")
    print(f"x = {x}")
else:
    print("No tiene soluciones reales")
# Out:
# Ingresa el valor de a: -1
# Ingresa el valor de b: 4
# Ingresa el valor de c: 3
# Dos soluciones reales:
# x1 = -0.6457513110645907
# x2 = 4.645751311064591

# %%
## 5 IF TERNARIO
a = float(input("Ingresa el valor de a: "))
b = float(input("Ingresa el valor de b: "))
c = float(input("Ingresa el valor de c: "))

discriminante = b * b - 4 * a * c

x1 = (-b + discriminante ** 0.5) / (2 * a) if (a != 0 and discriminante >= 0) else None
x2 = (-b - discriminante ** 0.5) / (2 * a) if (a != 0 and discriminante >= 0) else None

mensaje = "No es ecuación cuadrática" if a == 0 else (f"x1 = {str(x1)}  | x2 =   {str(x2)}" if discriminante >= 0 else "No tiene soluciones reales")

print(mensaje)
# Out:
# Ingresa el valor de a: -1
# Ingresa el valor de b: 4
# Ingresa el valor de c: 3
# x1 = -0.6457513110645907  | x2 =   4.645751311064591

# %%
## 6 IF/ELSE
numero = int(input("Ingresa un número: "))

if numero % 2 == 0:
    print(f"{numero} es par")
else:
    print(f"{numero} es impar")
# Out:
# Ingresa un número: 123712
# 123712 es par

# %%
## 6 IF/ELIF
numero = int(input("Ingresa un número: "))

if numero == 0:
    print("El número es cero, se considera par")
elif numero % 2 == 0:
    print(f"{numero} es par")
elif numero % 2 != 0:
    print(f"{numero} es impar")
# Out:
# Ingresa un número: 12372
# 12372 es par

# %%
## 6 IF TERNARIO
numero = int(input("Ingresa un número: "))

resultado = "par" if numero % 2 == 0 else "impar"

print(f"{numero} es {resultado}")
# Out:
# Ingresa un número: 12372
# 12372 es par

# %%
## 7 IF/ELSE
año = int(input("Ingresa un año: "))

if (año % 4 == 0 and año % 100 != 0) or (año % 400 == 0):
    print(f"{año} es bisiesto")
else:
    print(f"{año} no es bisiesto")
# Out:
# Ingresa un año: 2024
# 2024 es bisiesto

# %%
## 7 IF/ELIF
año = int(input("Ingresa un año: "))

if año <= 0:
    print("Ingresa un año válido")
elif año % 400 == 0:
    print(f"{año} es bisiesto")
elif año % 100 == 0:
    print(f"{año} NO es bisiesto")
elif año % 4 == 0:
    print(f"{año} es bisiesto")
else:
    print(f"{año} NO es bisiesto")
# Out:
# Ingresa un año: 2024
# 2024 es bisiesto

# %%
## 7 IF TERNARIO
año = int(input("Ingresa un año: "))

resultado = "es bisiesto" if (año % 4 == 0 and año % 100 != 0) or (año % 400 == 0) else "no es bisiesto"

print(año, resultado)
# Out:
# Ingresa un año: 2024
# 2024 es bisiesto

# %%
## 8 IF/ELSE
nombre = input("Ingresa tu nombre: ")
edad = int(input("Ingresa tu edad: "))

if edad >= 70:
    print(f"Hola, {nombre}, se le da prioridad en la fila.")
else:
    print(f"Hola, {nombre}, por favor espere su turno.")
# Out:
# Ingresa tu nombre: Orlandito
# Ingresa tu edad: 81
# Hola, Orlandito, se le da prioridad en la fila.

# %%
## 8 IF/ELIF
nombre = input("Ingresa tu nombre: ")
edad = int(input("Ingresa tu edad: "))

if edad < 18:
    print(f"Hola, {nombre}, eres menor de edad.")
elif edad < 70:
    print(f"Hola, {nombre}, por favor espere su turno.")
else:
    print(f"Hola, {nombre}, perteneces a la tercera edad. Se le da prioridad en la fila.")
# Out:
# Ingresa tu nombre: Mateo
# Ingresa tu edad: 18
# Hola Mateo , por favor espere su turno.

# %%
## 8 IF TERNARIO
nombre = input("Ingresa tu nombre: ")
edad = int(input("Ingresa tu edad: "))

mensaje = "se le da prioridad en la fila." if edad >= 70 else "por favor espere su turno."

print(f"Hola {nombre}, {mensaje}")
# Out:
# Ingresa tu nombre: Mateo
# Ingresa tu edad: 90
# Hola Mateo , se le da prioridad en la fila.

# %%
## 9 IF/ELSE1
n1 = float(input("Ingresa el primer número: "))
n2 = float(input("Ingresa el segundo número: "))
n3 = float(input("Ingresa el tercer número: "))

if n1 >= n2 and n1 >= n3:
    print(f"El mayor es: {n1}")
else:
    if n2 >= n3:
        print(f"El mayor es: {n2}")
    else:
        print(f"El mayor es: {n3}")
# Out:
# Ingresa el primer número: 3
# Ingresa el segundo número: 50
# Ingresa el tercer número: 234
# El mayor es: 234.0

# %%
## 9 IF/ELIF
n1 = float(input("Ingresa el primer número: "))
n2 = float(input("Ingresa el segundo número: "))
n3 = float(input("Ingresa el tercer número: "))

if n1 >= n2 and n1 >= n3:
    print(f"El mayor es: {n1}")
elif n2 >= n1 and n2 >= n3:
    print(f"El mayor es: {n2}")
else:
    print(f"El mayor es: {n3}")
# Out:
# Ingresa el primer número: 120
# Ingresa el segundo número: 341412
# Ingresa el tercer número: 4112312
# El mayor es: 4112312.0

# %%
## 9 IF TERNARIO
n1 = float(input("Ingresa el primer número: "))
n2 = float(input("Ingresa el segundo número: "))
n3 = float(input("Ingresa el tercer número: "))

mayor = n1 if (n1 >= n2 and n1 >= n3) else (n2 if n2 >= n3 else n3)

print(f"El mayor es: {mayor}")
# Out:
# Ingresa el primer número: 3212
# Ingresa el segundo número: 4321421
# Ingresa el tercer número: 4321421.9
# El mayor es: 4321421.9

# %%
## 10 IF/ELSE
l1 = float(input("Ingresa el primer lado: "))
l2 = float(input("Ingresa el segundo lado: "))
l3 = float(input("Ingresa el tercer lado: "))

if l1 == l2 and l2 == l3:
    print("El triángulo es equilátero")
else:
    if l1 == l2 or l2 == l3 or l1 == l3:
        print("El triángulo es isósceles")
    else:
        print("El triángulo es escaleno")
# Out:
# Ingresa el primer lado: 2
# Ingresa el segundo lado: 2
# Ingresa el tercer lado: 2
# El triángulo es equilátero

# %%
## 10 IF/ELIF
l1 = float(input("Ingresa el primer lado: "))
l2 = float(input("Ingresa el segundo lado: "))
l3 = float(input("Ingresa el tercer lado: "))

if l1 == l2 and l2 == l3:
    print("El triángulo es equilátero")
elif l1 == l2 or l2 == l3 or l1 == l3:
    print("El triángulo es isósceles")
else:
    print("El triángulo es escaleno")
# Out:
# Ingresa el primer lado: 2
# Ingresa el segundo lado: 2
# Ingresa el tercer lado: 5
# El triángulo es isósceles

# %%
## 10 IF TERNARIO
l1 = float(input("Ingresa el primer lado: "))
l2 = float(input("Ingresa el segundo lado: "))
l3 = float(input("Ingresa el tercer lado: "))

t = "equilátero" if (l1 == l2 and l2 == l3) else ("isósceles" if (l1 == l2 or l2 == l3 or l1 == l3) else "escaleno")

print(f"El triángulo es: {t}")
# Out:
# Ingresa el primer lado: 2
# Ingresa el segundo lado: 6
# Ingresa el tercer lado: 8
# El triángulo es: escaleno

# %%
## 11 IF/ELSE
nombre = input("Ingresa tu nombre: ")
peso = float(input("Ingresa tu peso en kg: "))
altura = float(input("Ingresa tu altura en metros: "))

imc = peso / (altura * altura)

if imc < 18.5:
    categoria = "Bajo peso"
    descripcion = "Debes aumentar tu ingesta calórica y consultar un nutricionista."
else:
    if imc < 25:
        categoria = "Normal"
        descripcion = "Sigue manteniendo tus hábitos saludables de alimentación y ejercicio."
    else:
        if imc < 30:
            categoria = "Sobrepeso"
            descripcion = "Se recomienda mejorar la dieta y aumentar la actividad física."
        else:
            categoria = "Obesidad"
            descripcion = "Es importante consultar a un médico para un plan de salud personalizado."

print(f"\nNombre: {nombre}")
print(f"IMC: {imc}")
print(f"Categoría: {categoria}")
print(f"Recomendación: {descripcion}")
# Out:
# Ingresa tu nombre: Mateo
# Ingresa tu peso en kg: 82
# Ingresa tu altura en metros: 1.77
#
# Nombre: Mateo
# IMC: 26.173832551310287
# Categoría: Sobrepeso
# Recomendación: Se recomienda mejorar la dieta y aumentar la actividad física.

# %%
## 11 IF/ELIF
nombre = input("Ingresa tu nombre: ")
peso = float(input("Ingresa tu peso en kg: "))
altura = float(input("Ingresa tu altura en metros: "))

imc = peso / (altura * altura)

if imc < 18.5:
    categoria = "Bajo peso"
    descripcion = "Debes aumentar tu ingesta calórica y consultar un nutricionista."
elif imc < 25:
    categoria = "Normal"
    descripcion = "Sigue manteniendo tus hábitos saludables de alimentación y ejercicio."
elif imc < 30:
    categoria = "Sobrepeso"
    descripcion = "Se recomienda mejorar la dieta y aumentar la actividad física."
else:
    categoria = "Obesidad"
    descripcion = "Es importante consultar a un médico para un plan de salud personalizado."

print(f"\nNombre: {nombre}")
print(f"IMC: {imc}")
print(f"Categoría: {categoria}")
print(f"Recomendación: {descripcion}")
# Out:
# Ingresa tu nombre: Mateo
# Ingresa tu peso en kg: 82
# Ingresa tu altura en metros: 1.77
#
# Nombre: Mateo
# IMC: 26.173832551310287
# Categoría: Sobrepeso
# Recomendación: Se recomienda mejorar la dieta y aumentar la actividad física.

# %%
## 11 IF TERNARIO
nombre = input("Ingresa tu nombre: ")
peso = float(input("Ingresa tu peso en kg: "))
altura = float(input("Ingresa tu altura en metros: "))

imc = peso / (altura * altura)

categoria = "Bajo peso" if imc < 18.5 else ("Normal" if imc < 25 else ("Sobrepeso" if imc < 30 else "Obesidad"))

descripcion = "Debes aumentar tu ingesta calórica y consultar un nutricionista." if imc < 18.5 else ("Sigue manteniendo tus hábitos saludables de alimentación y ejercicio." if imc < 25 else ("Se recomienda mejorar la dieta y aumentar la actividad física." if imc < 30 else "Es importante consultar a un médico para un plan de salud personalizado."))

print(f"\nNombre: {nombre}")
print(f"IMC: {imc}")
print(f"Categoría: {categoria}")
print(f"Recomendación: {descripcion}")
# Out:
# Ingresa tu nombre: Mateo
# Ingresa tu peso en kg: 82
# Ingresa tu altura en metros: 1.77
#
# Nombre: Mateo
# IMC: 26.173832551310287
# Categoría: Sobrepeso
# Recomendación: Se recomienda mejorar la dieta y aumentar la actividad física.

# %%
## 12 IF/ELSE
n1 = float(input("Ingresa el primer número: "))
op = input("Ingresa la operación (+, -, *, /): ")
n2 = float(input("Ingresa el segundo número: "))

if op == "+":
    print(f"Resultado: {n1 + n2}")
else:
    if op == "-":
        print(f"Resultado: {n1 - n2}")
    else:
        if op == "*":
            print(f"Resultado: {n1 * n2}")
        else:
            if op == "/":
                if n2 == 0:
                    print("No se puede dividir entre cero")
                else:
                    print(f"Resultado: {n1 / n2}")
            else:
                print("Operación no válida")
# Out:
# Ingresa el primer número: 3
# Ingresa la operación (+, -, *, /): +
# Ingresa el segundo número: 54
# Resultado: 57.0

# %%
## 12 IF/ELIF
n1 = float(input("Ingresa el primer número: "))
op = input("Ingresa la operación (+, -, *, /): ")
n2 = float(input("Ingresa el segundo número: "))

if op == "+":
    print(f"Resultado: {n1 + n2}")
elif op == "-":
    print(f"Resultado: {n1 - n2}")
elif op == "*":
    print(f"Resultado: {n1 * n2}")
elif op == "/" and n2 == 0:
    print("No se puede dividir entre cero")
elif op == "/":
    print(f"Resultado: {n1 / n2}")
else:
    print("Operación no válida")
# Out:
# Ingresa el primer número: 3
# Ingresa la operación (+, -, *, /): *
# Ingresa el segundo número: 6
# Resultado: 18.0

# %%
## 12 IF TERNARIO
n1 = float(input("Ingresa el primer número: "))
operacion = input("Ingresa la operación (+, -, *, /): ")
n2 = float(input("Ingresa el segundo número: "))

resultado = n1 + n2 if operacion == "+" else (n1 - n2 if operacion == "-" else (n1 * n2 if operacion == "*" else (n1 / n2 if operacion == "/" and n2 != 0 else "Operación inválida o división entre cero")))

print(f"Resultado: {resultado}")
# Out:
# Ingresa el primer número: 18
# Ingresa la operación (+, -, *, /): /
# Ingresa el segundo número: 3
# Resultado: 6.0

# %%
## 13 IF/ELSE
n = float(input("Ingresa la nota (0-100): "))

if n < 0 or n > 100:
    print("Nota inválida")
else:
    if n >= 90:
        print("Calificación: A")
    else:
        if n >= 80:
            print("Calificación: B")
        else:
            if n >= 70:
                print("Calificación: C")
            else:
                if n >= 60:
                    print("Calificación: D")
                else:
                    print("Calificación: F")
# Out:
# Ingresa la nota (0-100): 75
# Calificación: C

# %%
## 13 IF/ELIF
n = float(input("Ingresa la nota (0-100): "))

if n < 0 or n > 100:
    print("Nota inválida")
elif n >= 90:
    print("Calificación: A")
elif n >= 80:
    print("Calificación: B")
elif n >= 70:
    print("Calificación: C")
elif n >= 60:
    print("Calificación: D")
else:
    print("Calificación: F")
# Out:
# Ingresa la nota (0-100): 100
# Calificación: A

# %%
# 13 IF TERNARIO
nota = float(input("Ingresa la nota (0-100): "))

letra = "A" if nota >= 90 else ("B" if nota >= 80 else ("C" if nota >= 70 else ("D" if nota >= 60 else "F")))

print("Calificación:", letra if 0 <= nota <= 100 else "Nota inválida")
# Out:
# Ingresa la nota (0-100): -15
# Calificación: Nota inválida

# %%
## 14 IF/ELSE
n = int(input("Ingresa un número del 1 al 7: "))

if n == 1:
    print("Domingo")
else:
    if n == 2:
        print("Lunes")
    else:
        if n == 3:
            print("Martes")
        else:
            if n == 4:
                print("Miercoles")
            else:
                if n == 5:
                    print("Jueves")
                else:
                    if n == 6:
                        print("Viernes")
                    else:
                        if n == 7:
                            print("Sabado")
                        else:
                            print("Número inválido")
# Out:
# Ingresa un número del 1 al 7: 1
# Domingo

# %%
## 14 IF/ELIF
n = int(input("Ingresa un número del 1 al 7: "))

if n == 1:
    print("Domingo")
elif n == 2:
    print("Lunes")
elif n == 3:
    print("Martes")
elif n == 4:
    print("Miércoles")
elif n == 5:
    print("Jueves")
elif n == 6:
    print("Viernes")
elif n == 7:
    print("Sábado")
else:
    print("Número inválido")
# Out:
# Ingresa un número del 1 al 7: 4
# Miércoles

# %%
#14 IF TERNARIO
numero = int(input("Ingresa un número del 1 al 7: "))

dia = "Domingo" if numero == 1 else ("Lunes" if numero == 2 else ("Martes" if numero == 3 else ("Miércoles" if numero == 4 else ("Jueves" if numero == 5 else ("Viernes" if numero == 6 else ("Sábado" if numero == 7 else "Número inválido"))))))

print(f"El día es: {dia}")
# Out:
# Ingresa un número del 1 al 7: 2
# El día es: Lunes

# %%
## 15 IF/ELSE
a = float(input("Ingresa el primer lado: "))
b = float(input("Ingresa el segundo lado: "))
c = float(input("Ingresa el tercer lado: "))

if a + b > c and a + c > b and b + c > a:
    print("Sí forman un triángulo")
    if a == b and b == c:
        print("Tipo: Equilátero")
    else:
        if a == b or b == c or a == c:
            print("Tipo: Isósceles")
        else:
            print("Tipo: Escaleno")
else:
    print("Esos lados no forman un triángulo")
# Out:
# Ingresa el primer lado: 10
# Ingresa el segundo lado: 15
# Ingresa el tercer lado: 20
# Sí forman un triángulo
# Tipo: Escaleno

# %%
## 15 IF/ELIF
a = float(input("Ingresa el primer lado: "))
b = float(input("Ingresa el segundo lado: "))
c = float(input("Ingresa el tercer lado: "))

if not (a + b > c and a + c > b and b + c > a):
    print("Esos lados no forman un triángulo")
elif a == b and b == c:
    print("Sí forman un triángulo")
    print("Tipo: Equilátero")
elif a == b or b == c or a == c:
    print("Sí forman un triángulo")
    print("Tipo: Isósceles")
else:
    print("Sí forman un triángulo")
    print("Tipo: Escaleno")
# Out:
# Ingresa el primer lado: 7
# Ingresa el segundo lado: 7
# Ingresa el tercer lado: 7
# Sí forman un triángulo
# Tipo: Equilátero

# %%
## 15 IF TERNARIO
a = float(input("Ingresa el primer lado: "))
b = float(input("Ingresa el segundo lado: "))
c = float(input("Ingresa el tercer lado: "))

es_triangulo = "Sí forman un triángulo" if (a + b > c and a + c > b and b + c > a) else "No forman un triángulo"

tipo = "Equilátero" if (a == b and b == c) else ("Isósceles" if (a == b or b == c or a == c) else "Escaleno")

print(es_triangulo)
if es_triangulo == "Sí forman un triángulo":
    print(f"Tipo: {tipo}")
# Out:
# Ingresa el primer lado: 8
# Ingresa el segundo lado: 8
# Ingresa el tercer lado: 4
# Sí forman un triángulo
# Tipo: Isósceles
