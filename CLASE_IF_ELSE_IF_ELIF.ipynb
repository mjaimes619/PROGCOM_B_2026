# %% [markdown]
# <a href="https://colab.research.google.com/github/mjaimes619/PROGCOM_B_2026/blob/main/CLASE_IF_ELSE_IF_ELIF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
edad=int(input("Ingresa tu edad: "))

if edad>=18:
  print("Eres mayor de edad")
else:
  print("NO eres mayor de edad")
# Out:
# Ingresa tu edad: 19
# Eres mayor de edad

# %%
if edad<10: print("Eres un niño")
else:
  if edad>=10 and edad<14: print("Eres un preadolescente")
  else:
    if edad>=14 and edad<18: print("Eres un adolescente")
    else:
      if edad>=18 and edad<30: print("Eres un adulto joven")
      else: print("Eres un adulto")
# Out:
# Eres un adulto joven

# %% [markdown]
# Sintaxis
#
# ```
# if (C1): aqui se ejecuta codigo si C1 es TRUE
# elif(C2): aqui se ejecuta el codigo si C2 es TRUE
# elif(C3): aqui se ejecuta el codigo si C2 es TRUE
# ```
#
# ```
# # Esto tiene formato de código
# ```
