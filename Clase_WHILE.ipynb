# %% [markdown]
# <a href="https://colab.research.google.com/github/mjaimes619/PROGCOM_B_2026/blob/main/Clase_WHILE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #WHILE
# 1. Cuando no se sabe cuantas veces se repite una accion
# 2. Es gobernado por una condición de parada
# 3. Es necesaria una condicion inicial, la cual **DEBE** cambiar adentro del ciclo.
# Sintaxis
# ```
# while(condicion):
#   código a repetir
#   modificador de condición
# ```
# **OJO**
# La modificación de la condición puede darse de diferentes formas
# 1. Contador
# 2. Un acumulador
# 3. Cambio de bandera (trabajando con booleanos)
# 4. Con un input

# %%
#Suponer que la cantidad maxima de votantes son 10
#Suponer que son 5 candidatos
v1=0
v2=0
v3=0
v4=0
v5=0
vn=0
vb=0
for votos in range(10):
  id=input("Ingresa tu numero de documento: ")
  voto=input("Ingrese por quien quiere votar: \n1. Elefante blanco \n2. Pantera rosa \n3. Jotape Hernandez \n4. Paloma \n5. Quevedito \n6. Voto en blanco \n")
  if voto==1: v1+=1
  elif voto==2: v2+=1
  elif voto==3: v3+=1
  elif voto==4: v4+=1
  elif voto==5: v5+=1
  elif voto==6: vb+=1
  else: vn+=1
print(f" RESULTADOS: \n1 Elefante blanco: {v1} \n2. Pantera rosa: {v2} \n3. Jotape Hernandez: {v3} \n4. Paloma: {v4} \n5. Quevedito: {v5} \n6. Voto en blanco {vb} \Voto nulo: {vn}")
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\V'
# <>:20: SyntaxWarning: invalid escape sequence '\V'
# /tmp/ipykernel_635/1338009369.py:20: SyntaxWarning: invalid escape sequence '\V'
#   print(f" RESULTADOS: \n1 Elefante blanco: {v1} \n2. Pantera rosa: {v2} \n3. Jotape Hernandez: {v3} \n4. Paloma: {v4} \n5. Quevedito: {v5} \n6. Voto en blanco {vb} \Voto nulo: {vn}")
# Ingresa tu numero de documento: 105523
# Ingrese por quien quiere votar:
# 1. Elefante blanco
# 2. Pantera rosa
# 3. Jotape Hernandez
# 4. Paloma
# 5. Quevedito
# 6. Voto en blanco
# 5
# Ingresa tu numero de documento: 454545
# Ingrese por quien quiere votar:
# 1. Elefante blanco
# 2. Pantera rosa
# 3. Jotape Hernandez
# 4. Paloma
# 5. Quevedito
# 6. Voto en blanco
# 4
# Ingresa tu numero de documento: 14825636
# Ingrese por quien quiere votar:
# 1. Elefante blanco
# 2. Pantera rosa
# 3. Jotape Hernandez
# 4. Paloma
# 5. Quevedito
# 6. Voto en blanco
# 3
# Ingresa tu numero de documento: 58214845
# Ingrese por quien quiere votar:
# 1. Elefante blanco
# 2. Pantera rosa
# 3. Jotape Hernandez
# 4. Paloma
# 5. Quevedito
# 6. Voto en blanco
# 7
# Ingresa tu numero de documento: 546195
# Ingrese por quien quiere votar:
# 1. Elefante blanco
# 2. Pantera rosa
# 3. Jotape Hernandez
# 4. Paloma
# 5. Quevedito
# 6. Voto en blanco
# 5
# Ingresa tu numero de documento: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_635/1338009369.py in <cell line: 0>()
#      10 for votos in range(10):
#      11   id=input("Ingresa tu numero de documento: ")
# ---> 12   voto=input("Ingrese por quien quiere votar: \n1. Elefante blanco \n2. Pantera rosa \n3. Jotape Hernandez \n4. Paloma \n5. Quevedito \n6. Voto en blanco \n")
#      13   if voto==1: v1+=1
#      14   elif voto==2: v2+=1
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#Suponer que la cantidad maxima de votantes son 10
#Suponer que son 5 candidatos
v1=0
v2=0
v3=0
v4=0
v5=0
vn=0
vb=0
persona=0
votico="s"
while votico=="s" and persona<=10:
  id=input("Ingresa tu numero de documento: ")
  voto=input("Ingrese por quien quiere votar: \n1. Elefante blanco \n2. Pantera rosa \n3. Jotape Hernandez \n4. Paloma \n5. Quevedito \n6. Voto en blanco \n")
  if voto=="1": v1+=1
  elif voto=="2": v2+=1
  elif voto=="3": v3+=1
  elif voto=="4": v4+=1
  elif voto=="5": v5+=1
  elif voto=="6": vb+=1
  else: vn+=16
  print("Gracias por su voto")
  persona+=1
  votico=input("Hay personas antes de las 4:00PM? (s/n): ")
  print("")
print(f" RESULTADOS: \n1 Elefante blanco: {v1} \n2. Pantera rosa: {v2} \n3. Jotape Hernandez: {v3} \n4. Paloma: {v4} \n5. Quevedito: {v5} \n6. Voto en blanco {vb} \nVoto nulo: {vn}")
# Out:
# Ingresa tu numero de documento: 54154545
# Ingrese por quien quiere votar:
# 1. Elefante blanco
# 2. Pantera rosa
# 3. Jotape Hernandez
# 4. Paloma
# 5. Quevedito
# 6. Voto en blanco
# 5
# Gracias por su voto
# Hay personas antes de las 4:00PM? (s/n): s
#
# Ingresa tu numero de documento: 66464646
# Ingrese por quien quiere votar:
# 1. Elefante blanco
# 2. Pantera rosa
# 3. Jotape Hernandez
# 4. Paloma
# 5. Quevedito
# 6. Voto en blanco
# 3
# Gracias por su voto
# Hay personas antes de las 4:00PM? (s/n): s
#
# Ingresa tu numero de documento: 46
# Ingrese por quien quiere votar:
# 1. Elefante blanco
# 2. Pantera rosa
# 3. Jotape Hernandez
# 4. Paloma
# 5. Quevedito
# 6. Voto en blanco
# 9
# Gracias por su voto
# Hay personas antes de las 4:00PM? (s/n): s
#
# Ingresa tu numero de documento: 1
# Ingrese por quien quiere votar:
# 1. Elefante blanco
# 2. Pantera rosa
# 3. Jotape Hernandez
# 4. Paloma
# 5. Quevedito
# 6. Voto en blanco
# 1
# Gracias por su voto
# Hay personas antes de las 4:00PM? (s/n): n
#
#  RESULTADOS:
# 1 Elefante blanco: 1
# 2. Pantera rosa: 0
# 3. Jotape Hernandez: 1
# 4. Paloma: 0
# 5. Quevedito: 1
# 6. Voto en blanco 0
# Voto nulo: 1

# %%
# Suponer que la cantidad maxima de votantes son 10
# Suponer que son 5 candidatos
v1=0
v2=0
v3=0
v4=0
v5=0
vn=0
vb=0
persona=0
votico="s"
documentos_votados = []  # Almacena los IDs que ya votaron

while votico=="s" and persona<=10:
    id=input("Ingresa tu numero de documento: ")

    if id in documentos_votados:
        print(f"El documento {id} ya emitió su voto anteriormente.")
    else:
        documentos_votados.add(id)
        voto=input("Ingrese por quien quiere votar: \n1. Elefante blanco \n2. Pantera rosa \n3. Jotape Hernandez \n4. Paloma \n5. Quevedito \n6. Voto en blanco \n")
        if voto=="1": v1+=1
        elif voto=="2": v2+=1
        elif voto=="3": v3+=1
        elif voto=="4": v4+=1
        elif voto=="5": v5+=1
        elif voto=="6": vb+=1
        else: vn+=1
        print("Gracias por su voto")
        persona+=1

    votico=input("Hay personas antes de las 4:00PM? (s/n): ")
    print("")

print(f" RESULTADOS: \n1 Elefante blanco: {v1} \n2. Pantera rosa: {v2} \n3. Jotape Hernandez: {v3} \n4. Paloma: {v4} \n5. Quevedito: {v5} \n6. Voto en blanco {vb} \nVoto nulo: {vn}")

# %% [markdown]
# #LISTAS
# 1. Tienen index(numeracion)
# 2. Son finitas
# 3. Son mutables
# ```
# #Forma Canonica
# variable=[]
# # Extension
# variable[e,e1,e2,e3,...;en]
# #Comprension: formula que genera todos los elementos de la lista.
# ```

# %%
figura=["angelitos","estrella fugaz","dinosaurios","Malo"]
cantidad=[4,2,5,3]

# %% [markdown]
# ##Operaciones con listas
# 1. Recorrer listas
# 2. Verificar elementos dentro de la lista
# 3. Borrar elementos en la lista
# 4. Agregar elementos a la lista
# 5. Mutabilidad de las listas

# %%
#Funcion len calcula el tamaño de un dato
for elemento in range(len (figura)):
  print(figura[elemento],":", cantidad[elemento])
# Out:
# angelitos : 4
# estrella fugaz : 2
# dinosaurios : 5
# Malo : 3

# %%
for elemento in figura:
  print(elemento)
# Out:
# angelitos
# estrella fugaz
# dinosaurios
# Malo

# %% [markdown]
# #2. Verificar elementos dentro de lista

# %%
user=input("Qué figura quiere comprar?")
for elemento in range(len(figura)):
 if user==figura[elemento]: print("si hay🍪")
 else: print("No hay😧")
# Out:
# Qué figura quiere comprar?angelitos
# si hay🍪
# No hay😧
# No hay😧
# No hay😧

# %%
if user in figura: print("si hay🍪")
else: print("No hay😧")
# Out:
# si hay🍪

# %%
print("Si hay🍪" if user in figura else "No hay😧")
# Out:
# Si hay🍪

# %%
figura
# Out:
# ['angelitos', 'estrella fugaz', 'dinosaurios', 'Malo']

# %%
figura[3]="moñitos"
figura
# Out:
# ['angelitos', 'estrella fugaz', 'dinosaurios', 'moñitos']

# %%
#Para aumentar el tamaño de la lista
figura.append("dinosaurios")
figura
# Out:
# ['angelitos', 'estrella fugaz', 'dinosaurios', 'moñitos', 'dinosaurios']

# %% [markdown]
# #Recorriendo listas

# %%
#Para ver los elementos del 1 al 3
figura[1:4]
# Out:
# ['estrella fugaz', 'dinosaurios', 'moñitos']

# %%
figura[-1]
# Out:
# 'dinosaurios'

# %%
figura[len(figura)-1]
# Out:
# 'dinosaurios'

# %%
#Imprima todo hasta la posición 3
figura[:3]
# Out:
# ['angelitos', 'estrella fugaz', 'dinosaurios']

# %%
#Imprima desde la posición 1 hasta el final
figura[1:]
# Out:
# ['estrella fugaz', 'dinosaurios', 'moñitos', 'dinosaurios']

# %%
figura[-3]
# Out:
# 'dinosaurios'

# %%
figura[-3:-1]
# Out:
# ['dinosaurios', 'moñitos']

# %% [markdown]
# #Metodo de listas
# 1. Append. agregar un elemento a la lista. Aumentar el tamaño de la lista.OJO:
# 2. Diferente a reescribir un elemento de la lista.
# 3. len: Calcula el tamaño de un dato.
# 4. Count: Cuenta cuantos elementos iguales hay en una lista.
# 5. Copy: copia los elementos de una lista.

# %%
len(figura)
# Out:
# 5

# %%
figura.count("angelitos")
# Out:
# 1

# %%
galletas.append("chocolate")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_282/3920793333.py in <cell line: 0>()
# ----> 1 galletas.append("chocolate")
#
# NameError: name 'galletas' is not defined
