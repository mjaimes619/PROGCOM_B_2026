# %% [markdown]
# <a href="https://colab.research.google.com/github/mjaimes619/PROGCOM_B_2026/blob/main/Floristeria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
color_techo="amarillo"
color_pared="rosado"
cant_ventanas=3
cant_puertas=1
cant_pisos=1
cant_baños=2
color_marco_ventanas="negro"
decoracion_flores=False
letrero=True
nombre_letrero="el chamo"

# %%
def decorando_floristeria(a,b,c,d,e,f,g,h,letrero):
  color_techo=a
  color_pared=b
  cant_ventanas=c
  cant_puertas=d
  cant_pisos=e
  cant_baños=f
  color_marco_ventanas=g
  decoracion_flores=h #True si lo pusiste
  if h:flores_decoracion=input("Ingrese las flores con las que decoro ")
  if letrero: nombre_letrero=input("Cual es el nombre de la floristeria ")
print(f"Mi floristeria tiene: \nEl color de mi techo es {a} \n El color de la pared es {b} \n La cantidad de ventanas es{c} \n La cantidad de puertas es{d} \n la cantidad de pisos es {e} \n La cantidad de baños es {f} \n El color del marco de las ventanas es {g} \n Decoracion de flores {h}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3727/1247195291.py in <cell line: 0>()
#      10   if h:flores_decoracion=input("Ingrese las flores con las que decoro ")
#      11   if letrero: nombre_letrero=input("Cual es el nombre de la floristeria ")
# ---> 12 print(f"Mi floristeria tiene: \nEl color de mi techo es {a} \n El color de la pared es {b} \n La cantidad de ventanas es{c} \n La cantidad de puertas es{d} \n la cantidad de pisos es {e} \n La cantidad de baños es {f} \n El color del marco de las ventanas es {g} \n Decoracion de flores {h}")
#      13
#
# NameError: name 'a' is not defined

# %%
decorando_floristeria
# Out:
# <function __main__.decorando_floristeria(a, b, c, d, e, f, g, h, letrero)>
