# %% [markdown]
# <a href="https://colab.research.google.com/github/mjaimes619/PROGCOM_B_2026/blob/main/CLASE1_Conociendo_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Saludando al mundo

# %%
print("Hola mundo😁👌")
# Out:
# Hola mundo😁👌

# %% [markdown]
# ##INPUT
# Input es una función, que permite ingresar datos.
#
# Posee tre funciones
# 1. Lee: Se puede ingresar la informacion
# 2. Almacena: Guarda la informacion en una ariables (var)
# 3. Declara: Todos los daos almacenados los vuelve string
#
# Sintaxis
#
#
#
# ```
# var=input(Aqui va su impresion)
# ```
# Si se desea realizar una lectura de un tipo de dato diferente a string, se debe realizar una conversion de datos.
# Para ello, coloque el tipo de dato que desea convertir, y encierre el tipo original de dato entre parentesis.
#
#
# ```
# var=int(input()) #Aqui se va a trnasformar un dato de string a entero
# var2=float(input())#
# ```

# %%
print(f"La suma de las dos edades es {edad1+edad2}")
