# %% [markdown]
# <a href="https://colab.research.google.com/github/mjaimes619/PROGCOM_B_2026/blob/main/Clase_diccionario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DICCIONARIOS
# * No tienen index
# * Sabemos donde estan los elementos porque se manejan claves
# * Sintaxis
#
# ```
# variable={"clave":valor}
# ```
# * Donde la clave **SIEMPRE ES STRING**
# * Valor puede ser cualquier tipo de dato

# %%
Galleta=["angeles", "dinosaurios", "diablos"]
cant_galletas=[2,2,3]
precio_galletas=[50000, 2000, 20000]

# %%
galleta={"galleta":["angeles","dinosaurios","diablos"],
         "cant_galletas":[2,2,3],
         "precio_galletas":[50000,2000,20000]}

# %%
#Conocer las claves de las listas
galleta.keys()
# Out:
# dict_keys(['galleta', 'cant_galletas', 'precio_galletas'])

# %%
#Conocer todos los valores del diccionario
galleta.values()
# Out:
# dict_values([['angeles', 'dinosaurios', 'diablos'], [2, 2, 3], [50000, 2000, 20000]])

# %%
galleta.items()
# Out:
# dict_items([('galleta', ['angeles', 'dinosaurios', 'diablos']), ('cant_galletas', [2, 2, 3]), ('precio_galletas', [50000, 2000, 20000])])

# %%
for item in galleta.items():
  print(item)
# Out:
# ('galleta', ['angeles', 'dinosaurios', 'diablos'])
# ('cant_galletas', [2, 2, 3])
# ('precio_galletas', [50000, 2000, 20000])

# %%
#Agregar nuevas claves
galleta["Propietario"]="Alexandra"

# %%
galleta
# Out:
# {'galleta': ['angeles', 'dinosaurios', 'diablos'],
#  'cant_galletas': [2, 2, 3],
#  'precio_galletas': [50000, 2000, 20000],
#  'Propietario': 'Alexandra'}

# %%
galleta["precio_galletas"].append(21901)

# %%
galleta["precio_galletas"][0]
# Out:
# 50000

# %%
galleta
# Out:
# {'galleta': ['angeles', 'dinosaurios', 'diablos'],
#  'cant_galletas': [2, 2, 3],
#  'precio_galletas': [50000, 2000, 20000, 21901],
#  'Propietario': 'Alexandra'}
